# %% [markdown]
# ### 2023 Overlap MT1 and MT2 --> FN:
#
# Several core concepts from Midterms 1 and 2 reappear in the Final Exam, primarily:
#
# - Midterm 1, Q3: TIPS and their impact on the MV frontier.
#     - Overlap with Final Exam, Q7: Concerns about MV optimization out-of-sample. Both reference issues with MV optimization and portfolio allocation impacts.
# - Midterm 1, Q4: Classic MV optimization's instability and regularization.
#     - Overlap with Final Exam, Q7: Addresses the covariance matrix's instability and the regularization solution.
# - Midterm 2, Q1: Perfect hedging and LFPM implications.
#     - Overlap with Final Exam, Q1: LFPM errors in TS and CS tests, which discuss factor decomposition concepts.
# - Midterm 2, Q3: CAPM fits and r-squared relation to Sharpe ratios.
#     - Overlap with Final Exam, Q6: Discusses Sharpe ratios and CAPM's consistency when investors are not mean-variance.
# - Midterm 2, Q6: Momentum negative returns and pricing factors.
# - Indirect overlap with Final Exam, Q3: Momentum selection methods.
#
# #### Summary of Insights
# Several core concepts from Midterms 1 and 2 reappear in the Final Exam, primarily:
# - Mean-Variance Optimization (Midterm 1 Q3 & Q4 → Final Q7).
# - Factor Models (Midterm 2 Q1 → Final Q1).
# - Momentum Strategies (Midterm 2 Q5 & Q6 → Final Q3).
# - CAPM and Sharpe Ratios (Midterm 2 Q3 → Final Q6).

# %% [markdown]
# ### Overlap MT1 2023 --> MT1 2024:
#
# 1. 2023 Midterm 1 Q3 (TIPS impact on the MV frontier):
#
# - 2024 Midterm 1 Q1 revisits the role of TIPS in mean-variance optimization. Both questions involve:
#     - The diversification benefits of TIPS.
#     - Their correlation to other assets and implications for portfolio optimization.
# - Prediction: Questions related to TIPS' correlation, portfolio allocation, and their role in MV optimization could repeat on the 2024 Final Exam, potentially in broader or more theoretical contexts, like improving MV portfolio stability.
#
# 2. 2023 Midterm 1 Q4 (Regularization in MV optimization):
#
# - No direct repeat in 2024 Midterm 1.
# - Prediction: This concept could appear indirectly, particularly tied to out-of-sample performance or instability in portfolio weights, as seen in 2023 Final Q7.
#
# 3. 2024 Midterm 1 Q2 (Including/excluding intercepts in factor models):
#
# - Not directly linked to 2023 Midterm 1, but conceptually similar to 2023 Final Q1 discussing LFPM fit via cross-sectional and time-series tests.
# - Prediction: Factor models and regression setups, including their role in pricing and tracking, could feature on 2024 Final Exam.
#
# ### Overlap MT2 2023 --> MT2 2024:
#
# 1. 2023 Midterm 2 Q3 (Sharpe ratio relation in CAPM):
#
# - No direct repeat in 2024 Midterm 2 but 2024 Q1.3 discusses cumulative return certainty, which relates to the time horizon and variance scaling with CAPM assumptions.
# - Prediction: Sharpe ratios or risk-return measures, especially tied to time horizons or CAPM extensions, may appear on the 2024 Final Exam.
#
# 2. 2023 Midterm 2 Q5 (Momentum strategy risks and returns):
#
# - Directly mirrored in 2024 Midterm 2 Q1.5, comparing cryptocurrency and US equity momentum strategies.
# - Prediction: Momentum strategies and their risk profiles, particularly in alternative markets, could feature on the 2024 Final Exam, expanding the application of momentum to other assets or scenarios.
#
# 3. 2023 Midterm 2 Q1/Q2 (Factor models and pricing):
#
# - Concepts reappear in 2024 Midterm 2 Q1.1 (size factor decrease) and Q1.2 (MAE and factor addition).
# - Prediction: Expect factor model-related questions, potentially linked to testing methods (time-series or cross-sectional) or specific factors like size (SMB), as seen in 2023 Final Q1 and Q2.
#
# #### General Predictions for 2024 Final Exam
# Based on recurring themes from 2023 Final Exam, the following topics are likely candidates for the 2024 Final Exam:
#
# 1. Mean-Variance Optimization and Regularization:
# - Stability of weights, portfolio diversification, TIPS' impact (MV optimization under unique conditions).
#
# 2. Factor Models:
# - Cross-sectional vs. time-series tests, inclusion/exclusion of factors (like size, momentum, or new pricing factors).
# - LFPM errors or APT applications.
#
# 3. Momentum Strategies:
# - Comparison of momentum implementation in different markets (cryptocurrencies, US equities).
# - Risk and return profiles.
#
# 4. CAPM and Sharpe Ratios:
# - Cumulative returns over horizons, Sharpe ratio comparisons under specific assumptions.

# %% [markdown]
# ### Concepts from 2023 Midterms → 2024 Midterms → 2023 Final Exam
#
# **1. Mean-Variance Optimization and Regularization**
# - **2023 Midterm 1 Q4:** Discusses instability in the MV optimization process due to an ill-conditioned covariance matrix and how regularization helps stabilize weights.
# - **2024 Midterm 1 Q1**: Revisits MV optimization by analyzing TIPS' correlation with other assets and its impact on portfolio weights.
# - **2023 Final Q7:** Addresses out-of-sample instability in MV optimization caused by poor covariance matrix estimation and discusses regularization as a solution.
# - **Recurring Theme:** Stability of MV optimization and techniques to mitigate instability are revisited multiple times.
# - **Prediction for 2024 Final:** A similar question focusing on MV optimization, potentially with a broader theoretical framing or applications (e.g., real-world asset allocation).
#
# **2. Factor Models: Testing and Performance**
# - **2023 Midterm 2 Q1:** Discusses conditions under which factors act as a linear pricing model using the law of one price (LOOP).
# - **2024 Midterm 2 Q1.1-Q1.2:** Explores the role of factors, including their diminishing importance (e.g., SMB) and their impact on cross-sectional and time-series MAE.
# - **2023 Final Q1:** Focuses on LFPM and the use of cross-sectional and time-series tests to measure errors and model fit.
# - **Recurring Theme:** Factor models' performance, testing, and interpretation across different methods (LFPM, CAPM, and multi-factor models).
# - **Prediction for 2024 Final:** Questions testing the applicability and errors in factor models, possibly exploring new factors or alternative applications like crypto markets or emerging asset classes.
#
# **3. Momentum Strategies**
# - **2023 Midterm 2 Q5:** Discusses drawbacks of long-only momentum strategies in mutual funds (e.g., high market beta, limited diversification).
# - **2024 Midterm 2 Q1.5:** Examines differences in risk profiles for momentum strategies applied to cryptocurrencies versus US equities.
# - **2023 Final Q3:** Explores how altering momentum selection criteria (e.g., top/bottom 1%) impacts returns and volatility.
# - **Recurring Theme:** Momentum strategies' implementation, performance, and associated risks in different contexts.
# - **Prediction for 2024 Final:** Questions related to momentum strategies, potentially asking about their application to less traditional markets (e.g., crypto, commodities).
#
# **4. CAPM and Sharpe Ratios**
# - **2023 Midterm 2 Q3: Examines the relationship between Sharpe ratios and r-squared metrics under the CAPM framework.
# - **2024 Midterm 2 Q1.3:** Explores the certainty of cumulative returns over long versus short horizons, which indirectly ties to Sharpe ratios and CAPM predictions.
# - **2023 Final Q6:** Discusses consistency of CAPM predictions when higher Sharpe ratios than the market are observed.
# - **Recurring Theme:** Sharpe ratios' theoretical limits, time horizons, and their consistency under CAPM assumptions.
# - **Prediction for 2024 Final:** Sharpe ratio questions, potentially with a twist involving risk-return dynamics over different horizons or alternative pricing frameworks.
